# %%
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import xarray as xr
import cartopy.feature as cf

# %%
fig = plt.figure(figsize=(8,5))
ax = plt.subplot(1,1,1,projection= ccrs.PlateCarree())
file=xr.open_dataset('sst.mnmean.nc')

#ax.stock_img()
ax.add_feature(cf.COASTLINE)
ax.add_feature(cf.BORDERS)
ax.add_feature(cf.STATES)
ax.add_feature(cf.LAND)
ax.add_feature(cf.LAKES)
ax.add_feature(cf.OCEAN)
ax.set_extent([-3.5,2,4,12],crs=ccrs.PlateCarree())
axis=ax.gridlines(draw_labels=True,lw=1.5,color='grey',alpha=1,ls='-')
ax.set_title('GHANA')
ax.contourf(file.lon,file.lat,file.sst[0])

# %%
file
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 89, lon: 180, time: 128)
# Coordinates:
#   * lat      (lat) float32 88.0 86.0 84.0 82.0 80.0 ... -82.0 -84.0 -86.0 -88.0
#   * lon      (lon) float32 0.0 2.0 4.0 6.0 8.0 ... 350.0 352.0 354.0 356.0 358.0
#   * time     (time) datetime64[ns] 2010-01-01 2010-02-01 ... 2020-08-01
# Data variables:
#     sst      (time, lat, lon) float32 ...
# Attributes: (12/37)
#     climatology:               Climatology is based on 1971-2000 SST, Xue, Y....
#     description:               In situ data: ICOADS2.5 before 2007 and NCEP i...
#     keywords_vocabulary:       NASA Global Change Master Directory (GCMD) Sci...
#     keywords:                  Earth Science > Oceans > Ocean Temperature > S...
#     instrument:                Conventional thermometers
#     source_comment:            SSTs were observed by conventional thermometer...
#     ...                        ...
#     creator_url_original:      https://www.ncei.noaa.gov
#     license:                   No constraints on data access or use
#     comment:                   SSTs were observed by conventional thermometer...
#     summary:                   ERSST.v5 is developed based on v4 after revisi...
#     dataset_title:             NOAA Extended Reconstructed SST V5
#     data_modified:             2020-09-07
